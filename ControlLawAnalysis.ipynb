# %% [markdown]
# <script type="text/javascript">
#     on = "View input";
#     off = "Hide input"
#     function onoff(){
#       currentvalue = document.getElementById('onoff').value;
#       if(currentvalue == off){
#         document.getElementById("onoff").value=on;
#           $('div.input').hide();
#       }else{
#         document.getElementById("onoff").value=off;
#           $('div.input').show();
#       }
# }
# </script>
# <input type="button" class="ui-button ui-widget ui-state-default ui-corner-all ui-button-text-only" value="Hide input" id="onoff" onclick="onoff();">

# %%
# !make
import pandas as pd
import numpy as np
import matplotlib
import pylab
import matplotlib.pyplot as plt
from ZD_Utils import DataFrameUtils as dfutil
import UVVISAnalysisTools as uva
import UVVISPlots
from PyDyGraphs import pydygraphs
from IPython.display import display,Javascript,HTML,display_html,display_javascript
# %matplotlib inline

# Make plot sizes large:
figureSizeX, figureSizeY = 16,6
pylab.rcParams['figure.figsize'] = (figureSizeX, figureSizeY)

# Use a local copy of dygraphs.js so this notebook will work offline:
pydygraphs.useDygraphsLib("./PyDyGraphs/dygraph-combined.js")
# Out:
# make -C predictiveFilter
# make[1]: Entering directory `/home/daystar/BOPPSAnalysis/predictiveFilter'
# # make -C ./cdhlib
# make[1]: Leaving directory `/home/daystar/BOPPSAnalysis/predictiveFilter'
# make -C Centroid
# make[1]: Entering directory `/home/daystar/BOPPSAnalysis/Centroid'
# make[1]: Nothing to be done for `all'.
# make[1]: Leaving directory `/home/daystar/BOPPSAnalysis/Centroid'

# %%
## Load most recent file
workingDirectory = "/home/daystar/BOPPSAnalysis/" #/home/daystar/Desktop/FLIGHT2014/'
fname = workingDirectory + uva.findMostRecentFile(workingDirectory,starts_with="controllaw_",offset=0)
# fname = '/home/daystar/Desktop/FSMTestingJuly232014/controllaw_1406176042_128_2_2_0_0_1_0.2_1200_1100_500_500_10_1.2_1_400_20000_10_8_0_0_3_v2.dat'
# Out:
# ['controllaw_polarisfson_1411687348_v6.dat']
# ['controllaw_polarisfson_1411687348_v6.dat']

# %%
# Load data file:
reload(uva)
data,header = uva.loadControlLawFile(fname)
# print
# print 'Header columns:'
# print list(header.columns)
# print
# print 'Data columns:'
print list(data.columns)
# print
# uva.printStats(header, data)
# Out:
# Returning dataframes from controllaw_polarisfson_1411687348_v6.dat...
# ...
# ...
# NOT RUNNING PREDICTIVE FILTER ON DATA, USING MINIMAL DATASET
# ...
# Complete.
# ...

# %%
UVVISPlots.plotCentroids2D(header,data)

# %%
UVVISPlots.plotControllawSpeed(header, data)
# Out:
# <script src="./PyDyGraphs/dygraph-combined.js"></script>
#                     <table style="width: 1050px; border-style: hidden;">
#                         <tr>
#                             <th COLSPAN='1'>
#                                 <h1 align="center">Controllaw Speed Characterization</h1>
#                             </th>
#                         <tr><tr><td style="border-style: hidden;">
#     <script src="./PyDyGraphs/dygraph-combined.js"></script>
#     <table style="width: 1050px; border-style: hidden;">
#     <tr><td style="border-style: hidden;"><div id='Figure0' style="width: 1050px; height: 216px;"></div></td></tr>
#     <tr><td style="border-style: hidden;"><div style="text-align:right; width: 1050px; height: auto;"; id='Figure0_legend'></div></td></tr>
#     </table>
#     </td></tr><tr><td style="border-style: hidden;">
#     <script src="./PyDyGraphs/dygraph-combined.js"></script>
#     <table style="width: 1050px; border-style: hidden;">
# ...

# %%
UVVISPlots.plotControllawNumberofPoints(header,data)
# Out:
# <script src="./PyDyGraphs/dygraph-combined.js"></script>
#                     <table style="width: 1050px; border-style: hidden;">
#                         <tr>
#                             <th COLSPAN='1'>
#                                 <h1 align="center">Controllaw Number of Points</h1>
#                             </th>
#                         <tr><tr><td style="border-style: hidden;">
#     <script src="./PyDyGraphs/dygraph-combined.js"></script>
#     <table style="width: 1050px; border-style: hidden;">
#     <tr><td style="border-style: hidden;"><div id='Figure3' style="width: 1050px; height: 200px;"></div></td></tr>
#     <tr><td style="border-style: hidden;"><div style="text-align:right; width: 1050px; height: auto;"; id='Figure3_legend'></div></td></tr>
#     </table>
#     </td></tr><tr><td style="border-style: hidden;">
#     <script src="./PyDyGraphs/dygraph-combined.js"></script>
#     <table style="width: 1050px; border-style: hidden;">
# ...

# %%
UVVISPlots.plotFSMInputAndResiduals(header,data)
# Out:
# <script src="./PyDyGraphs/dygraph-combined.js"></script>
#                     <table style="width: 1050px; border-style: hidden;">
#                         <tr>
#                             <th COLSPAN='1'>
#                                 <h1 align="center">FSM Performance</h1>
#                             </th>
#                         <tr><tr><td style="border-style: hidden;">
#     <script src="./PyDyGraphs/dygraph-combined.js"></script>
#     <table style="width: 1050px; border-style: hidden;">
#     <tr><td style="border-style: hidden;"><div id='Figure6' style="width: 1050px; height: 200px;"></div></td></tr>
#     <tr><td style="border-style: hidden;"><div style="text-align:right; width: 1050px; height: auto;"; id='Figure6_legend'></div></td></tr>
#     </table>
#     </td></tr><tr><td style="border-style: hidden;">
#     <script src="./PyDyGraphs/dygraph-combined.js"></script>
#     <table style="width: 1050px; border-style: hidden;">
# ...

# %%
UVVISPlots.plotFSMPowerSpectrums(header,data)
# Out:
# <script src="./PyDyGraphs/dygraph-combined.js"></script>
#                     <table style="width: 1050px; border-style: hidden;">
#                         <tr>
#                             <th COLSPAN='3'>
#                                 <h1 align="center">Power Spectrum</h1>
#                             </th>
#                         <tr><tr><td style="border-style: hidden;">
#     <script src="./PyDyGraphs/dygraph-combined.js"></script>
#     <table style="width: 350px; border-style: hidden;">
#     <tr><td style="border-style: hidden;"><div id='Figure9' style="width: 350px; height: 300px;"></div></td></tr>
#     <tr><td style="border-style: hidden;"><div style="text-align:right; width: 350px; height: auto;"; id='Figure9_legend'></div></td></tr>
#     </table>
#     </td><td style="border-style: hidden;">
#     <script src="./PyDyGraphs/dygraph-combined.js"></script>
#     <table style="width: 350px; border-style: hidden;">
# ...

# %%
x=data["Az Residuals"].values
xm=uva.rollingRMS(x,10)*0.085
y=data["El Residuals"].values
ym=uva.rollingRMS(y,50)*0.085
data["Az RMS Res"] = xm
data["El RMS Res"] = ym
d1 = dfutil.colmask(data,['Time','Az RMS Res'])
d2 = dfutil.colmask(data,['Time','El RMS Res'])
[[a],[b]] = pydygraphs.subplot(2,1,title="Rolling RMS",height=350)
# plt.plot(xm)
a.plotDataFrame(d1,'Time');b.plotDataFrame(d2,'Time')
a.xlabel('Time [s]');b.xlabel('Time [s]')
a.ylabel('RMS Error Signal [arcsec]');b.ylabel('RMS Error Signal [arcsec]')
a.show();b.show()
# Out:
# <script src="./PyDyGraphs/dygraph-combined.js"></script>
#                     <table style="width: 1050px; border-style: hidden;">
#                         <tr>
#                             <th COLSPAN='1'>
#                                 <h1 align="center">Rolling RMS</h1>
#                             </th>
#                         <tr><tr><td style="border-style: hidden;">
#     <script src="./PyDyGraphs/dygraph-combined.js"></script>
#     <table style="width: 1050px; border-style: hidden;">
#     <tr><td style="border-style: hidden;"><div id='Figure15' style="width: 1050px; height: 175px;"></div></td></tr>
#     <tr><td style="border-style: hidden;"><div style="text-align:right; width: 1050px; height: auto;"; id='Figure15_legend'></div></td></tr>
#     </table>
#     </td></tr><tr><td style="border-style: hidden;">
#     <script src="./PyDyGraphs/dygraph-combined.js"></script>
#     <table style="width: 1050px; border-style: hidden;">
# ...
